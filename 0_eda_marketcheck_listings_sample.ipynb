# %% [markdown]
# # MarketCheck Listings Sample
# - File format for purchased file

# %%
# packages
import numpy as np
import pandas as pd

# %%
# data
df = pd.read_csv('data/marketcheck_listings_sample.csv',low_memory=False)
print(df.shape)
# Out:
# (10000, 86)

# %% [markdown]
# ## EDA

# %%
df.columns
# Out:
# Index(['id', 'vin', 'heading', 'more_info', 'price', 'msrp', 'miles',
#        'stock_no', 'year', 'make', 'model', 'trim', 'vehicle_type',
#        'body_type', 'body_subtype', 'drivetrain', 'fuel_type', 'engine',
#        'engine_block', 'engine_size', 'engine_measure', 'engine_aspiration',
#        'transmission', 'speeds', 'doors', 'cylinders', 'city_mpg',
#        'highway_mpg', 'interior_color', 'exterior_color',
#        'base_exterior_color', 'base_interior_color', 'is_certified',
#        'is_transfer', 'taxonomy_vin', 'model_code', 'scraped_at',
#        'status_date', 'first_scraped_at', 'dealer_id', 'source', 'seller_name',
#        'street', 'city', 'state', 'zip', 'latitude', 'longitude', 'country',
#        'seller_phone', 'seller_email', 'seller_type', 'listing_type',
#        'inventory_type', 'dealer_type', 'car_seller_name', 'car_address',
#        'car_street', 'car_city', 'car_state', 'car_zip', 'car_latitude',
#        'car_longitude', 'seller_comments', 'options', 'features',
#        'photo_links', 'photo_url', 'dom', 'dom_180', 'dom_active',
#        'currency_indicator', 'miles_indicator', 'carfax_1_owner',
#        'carfax_clean_title', 'loan_term', 'loan_apr', 'l_down_pay', 'l_emi',
#        'f_down_pay', 'f_down_pay_per', 'f_emi', 'lease_term', 'in_transit',
#        'in_transit_at', 'in_transit_days'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 50)

# %%
df.sample(5).T
# Out:
#                                                                   705   \
# id                                                       438dc0f0-4106
# vin                                                  3C4NJDBB9NT134881
# heading                                      Jeep Compass Latitude 4WD
# more_info            https://www.dancummins.net/inventory/used-2022...
# price                                                          27987.0
# msrp                                                           27987.0
# miles                                                          12893.0
# stock_no                                                         14110
# year                                                            2022.0
# make                                                              Jeep
# model                                                          Compass
# trim                                                          Latitude
# vehicle_type                                                     Truck
# body_type                                                          SUV
# body_subtype                                                       NaN
# drivetrain                                                         4WD
# fuel_type                                                     Unleaded
# engine                                                         2.4L I4
# engine_block                                                         I
# engine_size                                                        2.4
# engine_measure                                                     NaN
# engine_aspiration                                                  NaN
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          4.0
# city_mpg                                                          22.0
# highway_mpg                                                       30.0
# interior_color                                                   Black
# exterior_color                                                   White
# base_exterior_color                                              White
# base_interior_color                                              Black
# is_certified                                                       NaN
# is_transfer                                                        NaN
# taxonomy_vin                                                3C4NJDBBNT
# model_code                                                         NaN
# scraped_at                                        2022-10-06T20:32:19Z
# status_date                                       2022-10-09T20:26:23Z
# first_scraped_at                                  2021-12-19T16:05:56Z
# dealer_id                                                      1051164
# source                                                  dancummins.net
# seller_name                           dan cummins chevrolet-buick,inc.
# street                                 1020 Martin Luther King Jr Blvd
# city                                                             Paris
# state                                                               KY
# zip                                                              40361
# latitude                                                     38.217248
# longitude                                                   -84.213426
# country                                                             US
# seller_phone                                              877-392-5449
# seller_email                            michaelcarrigan@dancummins.com
# seller_type                                                     dealer
# listing_type                                                    dealer
# inventory_type                                                    used
# dealer_type                                                  franchise
# car_seller_name                                                    NaN
# car_address                                                        NaN
# car_street                                                         NaN
# car_city                                                           NaN
# car_state                                                          NaN
# car_zip                                                            NaN
# car_latitude                                                       NaN
# car_longitude                                                      NaN
# seller_comments                                                   4WD.
# options                                                            NaN
# features             AWD|Backup Camera|Blind Spot Monitor|Bluetooth...
# photo_links          https://s3.us-east-2.amazonaws.com/dealer-insp...
# photo_url            https://s3.us-east-2.amazonaws.com/dealer-insp...
# dom                                                                 32
# dom_180                                                              6
# dom_active                                                           6
# currency_indicator                                                 USD
# miles_indicator                                                  MILES
# carfax_1_owner                                                     0.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           NaN
# l_down_pay                                                         NaN
# l_emi                                                              NaN
# f_down_pay                                                         NaN
# f_down_pay_per                                                     NaN
# f_emi                                                              NaN
# lease_term                                                         NaN
# in_transit                                                           0
# in_transit_at                                                      NaN
# in_transit_days                                                    NaN
#
#                                                                   8280  \
# id                                                       c4b26787-31c0
# vin                                                  7SAYGDEF5NF452461
# heading                                 2022 Tesla Model Y PERFORMANCE
# more_info                          https://www.carmax.com/car/23051856
# price                                                          71998.0
# msrp                                                               NaN
# miles                                                            241.0
# stock_no                                                      23051856
# year                                                            2022.0
# make                                                             Tesla
# model                                                          Model Y
# trim                                                              Base
# vehicle_type                                                       NaN
# body_type                                                          SUV
# body_subtype                                                       NaN
# drivetrain                                                         4WD
# fuel_type                                                     Electric
# engine                                                             NaN
# engine_block                                                       NaN
# engine_size                                                        NaN
# engine_measure                                                     NaN
# engine_aspiration                                                  NaN
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          NaN
# city_mpg                                                         115.0
# highway_mpg                                                      106.0
# interior_color                                                   Black
# exterior_color                                                   White
# base_exterior_color                                              White
# base_interior_color                                              Black
# is_certified                                                       NaN
# is_transfer                                                        NaN
# taxonomy_vin                                                7SAYGDEFNF
# model_code                                                         NaN
# scraped_at                                        2022-10-08T05:45:06Z
# status_date                                       2022-10-09T05:44:49Z
# first_scraped_at                                  2022-07-06T09:38:53Z
# dealer_id                                                      1053104
# source                                                      carmax.com
# seller_name                                          carmax costa mesa
# street                                           3200 Harbor Boulevard
# city                                                        Costa Mesa
# state                                                               CA
# zip                                                              92626
# latitude                                                      33.68688
# longitude                                                   -117.91949
# country                                                             US
# seller_phone                                            (714) 481-8478
# seller_email                                                       NaN
# seller_type                                                     dealer
# listing_type                                                    dealer
# inventory_type                                                    used
# dealer_type                                                independent
# car_seller_name                                                    NaN
# car_address                                Costa Mesa California 92626
# car_street                                                         NaN
# car_city                                                    Costa Mesa
# car_state                                                           CA
# car_zip                                                          92626
# car_latitude                                                 33.679521
# car_longitude                                              -117.908791
# seller_comments                                                    NaN
# options                                                            NaN
# features             Power Locks|ABS Brakes|4WD/AWD|Automated Cruis...
# photo_links          https://img2.carmax.com/img/vehicles/23051856/...
# photo_url            https://img2.carmax.com/img/vehicles/23051856/...
# dom                                                                 96
# dom_180                                                             96
# dom_active                                                          96
# currency_indicator                                                 USD
# miles_indicator                                                  MILES
# carfax_1_owner                                                     NaN
# carfax_clean_title                                                 NaN
# loan_term                                                          NaN
# loan_apr                                                           0.0
# l_down_pay                                                         0.0
# l_emi                                                              0.0
# f_down_pay                                                         0.0
# f_down_pay_per                                                     0.0
# f_emi                                                              0.0
# lease_term                                                         NaN
# in_transit                                                           0
# in_transit_at                                                      NaN
# in_transit_days                                                    NaN
#
#                                                                   6330  \
# id                                                       90585b4f-a85f
# vin                                                  3GNKBBRA4MS528561
# heading                                   2021 Chevrolet Blazer LT SUV
# more_info            https://www.autonationfordmiami.com/used/Chevr...
# price                                                          30590.0
# msrp                                                           30590.0
# miles                                                          15551.0
# stock_no                                                      MS528561
# year                                                            2021.0
# make                                                         Chevrolet
# model                                                           Blazer
# trim                                                               1LT
# vehicle_type                                                     Truck
# body_type                                                          SUV
# body_subtype                                                       NaN
# drivetrain                                                         FWD
# fuel_type                                                     Unleaded
# engine                                                         2.5L I4
# engine_block                                                         I
# engine_size                                                        2.5
# engine_measure                                                     NaN
# engine_aspiration                                                  NaN
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          4.0
# city_mpg                                                          21.0
# highway_mpg                                                       27.0
# interior_color                                               Jet Black
# exterior_color                                                  Pewter
# base_exterior_color                                               Gray
# base_interior_color                                              Black
# is_certified                                                       NaN
# is_transfer                                                        NaN
# taxonomy_vin                                                3GNKBBRAMS
# model_code                                                         NaN
# scraped_at                                        2022-10-05T02:47:29Z
# status_date                                       2022-10-10T01:42:03Z
# first_scraped_at                                  2020-12-05T21:02:41Z
# dealer_id                                                      1010707
# source                                         autonationfordmiami.com
# seller_name                                      autonation ford miami
# street                                          16800 N.w. 57th Avenue
# city                                                     Miami Gardens
# state                                                               FL
# zip                                                              33015
# latitude                                                     25.926824
# longitude                                                   -80.294501
# country                                                             US
# seller_phone                                            (305) 707-0141
# seller_email                                                       NaN
# seller_type                                                     dealer
# listing_type                                                    dealer
# inventory_type                                                    used
# dealer_type                                                  franchise
# car_seller_name                  AutoNation Chevrolet South Clearwater
# car_address                                        Clearwater FL 33764
# car_street                                                         NaN
# car_city                                                    Clearwater
# car_state                                                           FL
# car_zip                                                          33764
# car_latitude                                                  27.93801
# car_longitude                                                -82.74621
# seller_comments      Keyless StartBluetooth ConnectionAudio System;...
# options                                                            NaN
# features             Automatic temperature control|Emergency commun...
# photo_links          https://pictures.dealer.com/a/autonationchevro...
# photo_url            https://pictures.dealer.com/a/autonationchevro...
# dom                                                                262
# dom_180                                                             96
# dom_active                                                          96
# currency_indicator                                                 USD
# miles_indicator                                                  MILES
# carfax_1_owner                                                     1.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           0.0
# l_down_pay                                                         0.0
# l_emi                                                              0.0
# f_down_pay                                                         0.0
# f_down_pay_per                                                     0.0
# f_emi                                                              0.0
# lease_term                                                         NaN
# in_transit                                                           0
# in_transit_at                                                      NaN
# in_transit_days                                                    NaN
#
#                                                                   3894  \
# id                                                       05ac9591-e9b9
# vin                                                  1GKKNMLS9LZ134850
# heading                                            2020 GMC Acadia SLT
# more_info            https://doughenrygreenville.com/vdp/18955959/U...
# price                                                          34961.0
# msrp                                                           34961.0
# miles                                                          62896.0
# stock_no                                                         Z5719
# year                                                            2020.0
# make                                                               GMC
# model                                                           Acadia
# trim                                                               SLT
# vehicle_type                                                       NaN
# body_type                                                          SUV
# body_subtype                                                       NaN
# drivetrain                                                         FWD
# fuel_type                                                     Unleaded
# engine                                                         3.6L V6
# engine_block                                                       NaN
# engine_size                                                        NaN
# engine_measure                                                     NaN
# engine_aspiration                                                  NaN
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          NaN
# city_mpg                                                          21.0
# highway_mpg                                                       28.0
# interior_color                                                     NaN
# exterior_color                                    Cocoa/Light Ash Gray
# base_exterior_color                                               Gray
# base_interior_color                                                NaN
# is_certified                                                       NaN
# is_transfer                                                        NaN
# taxonomy_vin                                                1GKKNMLSLZ
# model_code                                                         NaN
# scraped_at                                        2022-09-28T17:59:44Z
# status_date                                       2022-10-09T19:19:00Z
# first_scraped_at                                  2022-03-14T23:47:22Z
# dealer_id                                                      1027068
# source                                         doughenrygreenville.com
# seller_name                                   doug henry of greenville
# street                                              3211 S Memorial Dr
# city                                                        Greenville
# state                                                               NC
# zip                                                              27834
# latitude                                                     35.572507
# longitude                                                   -77.398869
# country                                                             US
# seller_phone                                              252-321-3684
# seller_email                                        doughcit@yahoo.com
# seller_type                                                     dealer
# listing_type                                                    dealer
# inventory_type                                                    used
# dealer_type                                                independent
# car_seller_name                                                    NaN
# car_address                                                        NaN
# car_street                                                         NaN
# car_city                                                           NaN
# car_state                                                          NaN
# car_zip                                                            NaN
# car_latitude                                                       0.0
# car_longitude                                                      0.0
# seller_comments      2020 GMC Acadia SLT CLEAN VEHICLE HISTORY REPO...
# options              Axle| 3.47 final drive ratio (Standard with (L...
# features                                                           NaN
# photo_links          https://imagescdn.dealercarsearch.com/Media/98...
# photo_url            https://imagescdn.dealercarsearch.com/Media/98...
# dom                                                                210
# dom_180                                                            210
# dom_active                                                          92
# currency_indicator                                                 USD
# miles_indicator                                                  MILES
# carfax_1_owner                                                     0.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           0.0
# l_down_pay                                                         0.0
# l_emi                                                              0.0
# f_down_pay                                                         0.0
# f_down_pay_per                                                     0.0
# f_emi                                                              0.0
# lease_term                                                         NaN
# in_transit                                                           0
# in_transit_at                                                      NaN
# in_transit_days                                                    NaN
#
#                                                                   7952
# id                                                       810172d7-49ed
# vin                                                  5UXCR6C09L9B35884
# heading                       BMW X5 xDrive40i Sports Activity Vehicle
# more_info            https://www.bmwofgreenwich.com/inventory/certi...
# price                                                          55950.0
# msrp                                                           74145.0
# miles                                                          22975.0
# stock_no                                                      9B35884M
# year                                                            2020.0
# make                                                               BMW
# model                                                               X5
# trim                                                               40i
# vehicle_type                                                     Truck
# body_type                                                          SUV
# body_subtype                                                       NaN
# drivetrain                                                         4WD
# fuel_type                                             Premium Unleaded
# engine                                                         3.0L I6
# engine_block                                                         I
# engine_size                                                        3.0
# engine_measure                                                     NaN
# engine_aspiration                                                  NaN
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          6.0
# city_mpg                                                          20.0
# highway_mpg                                                       26.0
# interior_color                                                   Black
# exterior_color                                  Phytonic Blue Metallic
# base_exterior_color                                               Blue
# base_interior_color                                              Black
# is_certified                                                       1.0
# is_transfer                                                        NaN
# taxonomy_vin                                                5UXCR6C0L9
# model_code                                                         NaN
# scraped_at                                        2022-09-21T13:40:49Z
# status_date                                       2022-10-10T01:30:54Z
# first_scraped_at                                  2019-11-09T08:54:04Z
# dealer_id                                                      1013399
# source                                              bmwofgreenwich.com
# seller_name                                           bmw of greenwich
# street                                                355 W Putnam Ave
# city                                                         Greenwich
# state                                                               CT
# zip                                                               6830
# latitude                                                     41.023233
# longitude                                                   -73.638612
# country                                                             US
# seller_phone                                            (844) 353-5801
# seller_email                               KZallo@penskeautomotive.com
# seller_type                                                     dealer
# listing_type                                                    dealer
# inventory_type                                                    used
# dealer_type                                                  franchise
# car_seller_name                                                    NaN
# car_address                                          BMW of Mamaroneck
# car_street                                                         NaN
# car_city                                                           NaN
# car_state                                                          NaN
# car_zip                                                            NaN
# car_latitude                                                       0.0
# car_longitude                                                      0.0
# seller_comments      Recent Arrival! Odometer is 6272 miles below m...
# options                                                            NaN
# features             Air Conditioning|Climate Control|Dual Zone Cli...
# photo_links          https://s3.us-east-2.amazonaws.com/dealer-insp...
# photo_url            https://s3.us-east-2.amazonaws.com/dealer-insp...
# dom                                                                 34
# dom_180                                                             20
# dom_active                                                          20
# currency_indicator                                                 USD
# miles_indicator                                                  MILES
# carfax_1_owner                                                     0.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           0.0
# l_down_pay                                                         0.0
# l_emi                                                              0.0
# f_down_pay                                                         0.0
# f_down_pay_per                                                     0.0
# f_emi                                                              0.0
# lease_term                                                         NaN
# in_transit                                                           0
# in_transit_at                                                      NaN
# in_transit_days                                                    NaN
