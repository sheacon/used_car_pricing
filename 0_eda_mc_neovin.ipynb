# %% [markdown]
# # MarketCheck Listings Samples
# - Listings
# - NeoVIN

# %% [markdown]
# ## Environment

# %%
# packages
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 50)

# %% [markdown]
# # Load NeoVIN

# %%
# neovin data
df = pd.read_excel('data/marketcheck_neovin_sample.xlsx')
print(df.shape)
# Out:
# (3042, 44)

# %%
df.columns
# Out:
# Index(['vin', 'squish_vin', 'year', 'make', 'model', 'listing_confidence',
#        'trim', 'trim_confidence', 'version', 'version_confidence',
#        'transmission', 'transmission_description', 'transmission_confidence',
#        'drivetrain', 'engine', 'fuel_type', 'powertrain_type', 'doors',
#        'body_type', 'body_subtype', 'weight', 'width', 'height', 'length',
#        'city_mpg', 'highway_mpg', 'seating_capacity', 'manufacturer_code',
#        'package_code', 'package_description', 'msrp', 'installed_options_msrp',
#        'delivery_charges', 'combined_msrp', 'interior_color', 'exterior_color',
#        'options_packages', 'installed_options_details', 'features',
#        'installed_equipment', 'available_options_details', 'country',
#        'delivery_date', 'decode_version'],
#       dtype='object')

# %%
df.sample(5).T
# Out:
#                                                                         610   \
# vin                                                        3N1AB7AP8EY339138
# squish_vin                                                       3N1AB7AP_EY
# year                                                                    2014
# make                                                                  Nissan
# model                                                                 Sentra
# listing_confidence              mc_listings|used|dealer|franchise|1|alt_opts
# trim                                                                      SV
# trim_confidence            mc_listings|used|dealer|franchise|orig|exact_m...
# version                                                           1.8 SV CVT
# version_confidence                                                    single
# transmission                                                       Automatic
# ...
