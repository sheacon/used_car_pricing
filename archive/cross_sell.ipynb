# %% [markdown]
# # Cross-Sell Sample Data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/cross_sell_sample.csv')
df.shape
# Out:
# (1438, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1438 entries, 0 to 1437
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vin               1438 non-null   object
#  1   Make_Type         1438 non-null   object
#  2   Reg_Class         1438 non-null   object
#  3   Body              1438 non-null   object
#  4   Segment           1436 non-null   object
#  5   Make              1438 non-null   object
#  6   Model             1438 non-null   object
#  7   Trim              1422 non-null   object
#  8   Odometer          1438 non-null   object
#  9   sprice            1438 non-null   int64
#  10  Year              1438 non-null   int64
#  11  BuyHere           59 non-null     object
#  12  Seller            1438 non-null   object
#  13  seller_address    1378 non-null   object
#  14  Seller_City       1378 non-null   object
#  15  Seller_State      1381 non-null   object
# ...

# %%
df.sample(5).T
# Out:
#                                      162                            244   \
# Vin                     2V4RW3D19AR237044              3GCPCRECXJG185264
# Make_Type                          Import                       Domestic
# Reg_Class                             Car                          Truck
# Body                                   VN                             PU
# Segment                           MINIVAN              FULL-SIZED PICKUP
# Make                           Volkswagen                      Chevrolet
# Model                              Routan                 Silverado 1500
# Trim                                   SE                             LT
# Odometer                           EXEMPT                          92009
# sprice                                  0                          33068
# Year                                 2010                           2018
# BuyHere                               NaN                            NaN
# ...

# %%
df['sprice'].describe()
# Out:
# count      1438.000000
# mean      21947.909597
# std       18196.916021
# min           0.000000
# 25%        6500.000000
# 50%       20554.000000
# 75%       32173.500000
# max      159995.000000
# Name: sprice, dtype: float64

# %%
df['sprice'].hist()
# Out:
# <AxesSubplot:>
