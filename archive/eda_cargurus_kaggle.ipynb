# %% [markdown]
# # CarGurus.com Scrape
# - Notes: scraped September 2020. Good data. Description, major options, etc
# - 3m obs, 66 vars
# - https://www.kaggle.com/datasets/ananaymital/us-used-cars-dataset
# - original filename used_cars_data.csv

# %% [markdown]
# ### Other dataset-specific notebooks to review
# - https://www.kaggle.com/code/alvarolozanoalonso/mileage-tfm-15-09-2021
# - https://www.kaggle.com/code/fr3shk/vehicle-price-prediction-part-1
# - https://www.kaggle.com/code/fr3shk/vehicle-price-prediction-part-2

# %% [markdown]
# ## Environment

# %%
# versions

from platform import python_version
print('python',python_version())

from importlib.metadata import version
print('numpy',version('numpy'))
print('pandas',version('pandas'))
print('pandas_profiling',version('pandas_profiling'))
# Out:
# python 3.9.13
# numpy 1.21.5
# pandas 1.4.4
# pandas_profiling 3.5.0

# %%
import random
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from uszipcode import SearchEngine # https://pypi.org/project/uszipcode/ / https://www.pythonpool.com/uszipcode-python/
import missingno as msno # https://github.com/ResidentMario/missingno

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 50)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Load and Inspect

# %%
df = pd.read_parquet('data/cargurus_kaggle.parquet')

# %%
(df.memory_usage().sum() / 1024**2).round()
# Out:
# 631.8689498901367

# %%
# drop duplicates by vin
print(df.shape)
df.drop_duplicates(subset = 'vin',inplace=True)
print(df.shape)
# Out:
# (3000040, 64)
# (3000000, 64)

# %%
# drop unneeded obs
df = df[df['is_new'] == False]
print(df.shape)
# Out:
# (1528979, 64)

# %%
# drop columns unimportant to model
df.drop(columns=['bed_height' # all '--'
                ,'bed' # mostly na (98%) and redundant with bed_length anyway
                ,'listing_id'
                ,'main_picture_url'
                ,'savings_amount' # involves cargurus price projection
                ,'sp_id' # dealer id
                ,'sp_name' # dealer name
                ,'wheel_system_display' # redundant with wheel_system
                ] 
    ,inplace=True)
print(df.shape)
# Out:
# (1528979, 56)
# /var/folders/nl/d1z3_54n5kb053_jgq9kvjnh0000gn/T/ipykernel_45079/530667432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['bed_height' # all '--'

# %%
# drop empty columns
df.dropna(axis = 'columns', how = 'all', inplace = True)
print(df.shape)
# Out:
# (1528979, 55)
# /var/folders/nl/d1z3_54n5kb053_jgq9kvjnh0000gn/T/ipykernel_45079/628516233.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis = 'columns', how = 'all', inplace = True)

# %%
# rename fields
df.rename(columns={'city_fuel_economy':'mpg_city'
                    ,'fuel_tank_volume':'fuel_capacity'
                    ,'highway_fuel_economy':'mpg_hwy'
                    ,'exterior_color':'color_exterior'
                    ,'interior_color':'color_interior'
                    ,'maximum_seating':'seats'
                    ,'year':'model_year'
                    ,'back_legroom':'legroom_back'
                    ,'front_legroom':'legroom_front'
                    ,'height':'dim_height'
                    ,'length':'dim_length'
                    ,'width':'dim_width'
                    ,'wheelbase':'dim_wheelbase'
                    ,'bed_length':'dim_bed'
                    ,'engine_displacement':'engine_disp'
                    ,'engine_cylinders':'engine_cyl'
                    ,'torque':'engine_torque'
                    ,'horsepower':'engine_hp'
                    ,'isCab':'is_taxi'
                    ,
                    }, inplace=True)

# sort columns
df = df.reindex(sorted(df.columns), axis=1)
# Out:
# /var/folders/nl/d1z3_54n5kb053_jgq9kvjnh0000gn/T/ipykernel_45079/596413218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'city_fuel_economy':'mpg_city'

# %%
print(df.columns)
# Out:
# Index(['body_type', 'cabin', 'city', 'color_exterior', 'color_interior',
#        'daysonmarket', 'dealer_zip', 'description', 'dim_bed', 'dim_height',
#        'dim_length', 'dim_wheelbase', 'dim_width', 'engine_cyl', 'engine_disp',
#        'engine_hp', 'engine_torque', 'engine_type', 'fleet', 'frame_damaged',
#        'franchise_dealer', 'franchise_make', 'fuel_capacity', 'fuel_type',
#        'has_accidents', 'is_cpo', 'is_new', 'is_oemcpo', 'is_taxi', 'latitude',
#        'legroom_back', 'legroom_front', 'listed_date', 'listing_color',
#        'longitude', 'major_options', 'make_name', 'mileage', 'model_name',
#        'model_year', 'mpg_city', 'mpg_hwy', 'owner_count', 'power', 'price',
#        'salvage', 'seats', 'seller_rating', 'theft_title', 'transmission',
#        'transmission_display', 'trimId', 'trim_name', 'vin', 'wheel_system'],
#       dtype='object')

# %%
df.sample(5).T
# Out:
#                                                                 1971040  \
# body_type                                                     Hatchback
# cabin                                                               NaN
# city                                                           Billings
# color_exterior                                                 CHARCOAL
# color_interior                                                    Black
# daysonmarket                                                         16
# dealer_zip                                                        59101
# description           STOP BY PERFORMANCE AUTO SALES TODAY, YOUR BES...
# dim_bed                                                             NaN
# dim_height                                                      58.4 in
# dim_length                                                     165.8 in
# dim_wheelbase                                                  101.5 in
# dim_width                                                       69.3 in
# engine_cyl                                                           I4
# engine_disp                                                      2000.0
# engine_hp                                                           200
# engine_torque                                     207 lb-ft @ 1,800 RPM
# engine_type                                                          I4
# fleet                                                             False
# frame_damaged                                                     False
# franchise_dealer                                                  False
# franchise_make                                                      NaN
# fuel_capacity                                                  14.5 gal
# fuel_type                                                      Gasoline
# has_accidents                                                      True
# is_cpo                                                              NaN
# is_new                                                            False
# is_oemcpo                                                           NaN
# is_taxi                                                           False
# latitude                                                      45.763401
# legroom_back                                                    35.3 in
# legroom_front                                                   41.2 in
# listed_date                                                    24000448
# listing_color                                                     BLACK
# longitude                                                   -108.540001
# major_options                          ['Alloy Wheels', 'Heated Seats']
# make_name                                                    Volkswagen
# mileage                                                        124359.0
# model_name                                                          GTI
# model_year                                                         2010
# mpg_city                                                           21.0
# mpg_hwy                                                            31.0
# owner_count                                                           4
# power                                                200 hp @ 5,100 RPM
# price                                                            7577.0
# salvage                                                            True
# seats                                                           5 seats
# seller_rating                                         4.333333333333333
# theft_title                                                       False
# transmission                                                          M
# transmission_display                                             Manual
# trimId                                                           t37170
# trim_name                                               2.0T 2-Door FWD
# vin                                                   WVWEV7AJ2AW325786
# wheel_system                                                        FWD
#
#                                                                 366772   \
# body_type                                               SUV / Crossover
# cabin                                                               NaN
# city                                                          Baltimore
# color_exterior                                                    Black
# color_interior                                                Jet Black
# daysonmarket                                                          1
# dealer_zip                                                        21224
# description           TENT SALE EVENT ALL MONTH LONG . (125% OF KELL...
# dim_bed                                                             NaN
# dim_height                                                      66.3 in
# dim_length                                                     187.8 in
# dim_wheelbase                                                  112.5 in
# dim_width                                                       72.5 in
# engine_cyl                                                           I4
# engine_disp                                                      2400.0
# engine_hp                                                           182
# engine_torque                                     172 lb-ft @ 4,900 RPM
# engine_type                                                          I4
# fleet                                                             False
# frame_damaged                                                     False
# franchise_dealer                                                   True
# franchise_make                                                Chevrolet
# fuel_capacity                                                  18.8 gal
# fuel_type                                                      Gasoline
# has_accidents                                                      True
# is_cpo                                                              NaN
# is_new                                                            False
# is_oemcpo                                                           NaN
# is_taxi                                                           False
# latitude                                                      39.296299
# legroom_back                                                    39.9 in
# legroom_front                                                   41.2 in
# listed_date                                                    24000448
# listing_color                                                     BLACK
# longitude                                                      -76.5308
# major_options                         ['Alloy Wheels', 'Backup Camera']
# make_name                                                     Chevrolet
# mileage                                                         36966.0
# model_name                                                      Equinox
# model_year                                                         2017
# mpg_city                                                           21.0
# mpg_hwy                                                            31.0
# owner_count                                                           2
# power                                                182 hp @ 6,700 RPM
# price                                                           16914.0
# salvage                                                           False
# seats                                                           5 seats
# seller_rating                                        3.9444444444444446
# theft_title                                                       False
# transmission                                                          A
# transmission_display                        6-Speed Automatic Overdrive
# trimId                                                           t67423
# trim_name                                                        LS FWD
# vin                                                   2GNALBEK1H1545150
# wheel_system                                                        FWD
#
#                                                                 2676897  \
# body_type                                               SUV / Crossover
# cabin                                                               NaN
# city                                                         Brownfield
# color_exterior                                             Summit White
# color_interior                                                    Shale
# daysonmarket                                                         49
# dealer_zip                                                        79316
# description           Summary: **ONE OWNER**, **CLEAN AUTOCHECK**, A...
# dim_bed                                                             NaN
# dim_height                                                      69.9 in
# dim_length                                                     204.3 in
# dim_wheelbase                                                  120.9 in
# dim_width                                                       89.3 in
# engine_cyl                                                           V6
# engine_disp                                                      3600.0
# engine_hp                                                           310
# engine_torque                                     266 lb-ft @ 2,800 RPM
# engine_type                                                          V6
# fleet                                                              True
# frame_damaged                                                     False
# franchise_dealer                                                   True
# franchise_make                                                     Ford
# fuel_capacity                                                  19.4 gal
# fuel_type                                                      Gasoline
# has_accidents                                                     False
# is_cpo                                                              NaN
# is_new                                                            False
# is_oemcpo                                                           NaN
# is_taxi                                                            True
# latitude                                                      33.196999
# legroom_back                                                    38.9 in
# legroom_front                                                   41.2 in
# listed_date                                                    24000448
# listing_color                                                     WHITE
# longitude                                                   -102.274002
# major_options         ['Alloy Wheels', 'Bluetooth', 'Backup Camera',...
# make_name                                                         Buick
# mileage                                                         43256.0
# model_name                                                      Enclave
# model_year                                                         2019
# mpg_city                                                           18.0
# mpg_hwy                                                            26.0
# owner_count                                                           1
# power                                                310 hp @ 6,800 RPM
# price                                                           26905.0
# salvage                                                           False
# seats                                                           7 seats
# seller_rating                                                       4.5
# theft_title                                                       False
# transmission                                                          A
# transmission_display                                  9-Speed Automatic
# trimId                                                           t79386
# trim_name                                                   Essence FWD
# vin                                                   5GAERBKW6KJ189275
# wheel_system                                                        FWD
#
#                                                                 655819   \
# body_type                                                  Pickup Truck
# cabin                                                               NaN
# city                                                       North Canton
# color_exterior                                                     GRAY
# color_interior                                                     None
# daysonmarket                                                         18
# dealer_zip                                                        44720
# description           Family Owned and Operated We offer Easy financ...
# dim_bed                                                         76.3 in
# dim_height                                                      74.7 in
# dim_length                                                     227.7 in
# dim_wheelbase                                                  140.5 in
# dim_width                                                       79.9 in
# engine_cyl                                                           V8
# engine_disp                                                      5900.0
# engine_hp                                                           245
# engine_torque                                     335 lb-ft @ 3,200 RPM
# engine_type                                                          V8
# fleet                                                             False
# frame_damaged                                                     False
# franchise_dealer                                                  False
# franchise_make                                                      NaN
# fuel_capacity                                                    26 gal
# fuel_type                                                      Gasoline
# has_accidents                                                      True
# is_cpo                                                              NaN
# is_new                                                            False
# is_oemcpo                                                           NaN
# is_taxi                                                           False
# latitude                                                      40.885601
# legroom_back                                                    36.4 in
# legroom_front                                                     41 in
# listed_date                                                    24000448
# listing_color                                                      GRAY
# longitude                                                    -81.432503
# major_options                                                      None
# make_name                                                         Dodge
# mileage                                                        173727.0
# model_name                                                     RAM 1500
# model_year                                                         2003
# mpg_city                                                           13.0
# mpg_hwy                                                            17.0
# owner_count                                                           4
# power                                                245 hp @ 4,000 RPM
# price                                                            5995.0
# salvage                                                           False
# seats                                                           6 seats
# seller_rating                                                       4.0
# theft_title                                                       False
# transmission                                                          A
# transmission_display                                          Automatic
# trimId                                                           t22108
# trim_name                                              SLT Quad Cab RWD
# vin                                                   1D7HA18D23S220705
# wheel_system                                                        RWD
#
#                                                                 1603068
# body_type                                                         Sedan
# cabin                                                               NaN
# city                                                            Decatur
# color_exterior                                Celestial Silver Metallic
# color_interior                                                     None
# daysonmarket                                                        127
# dealer_zip                                                        35601
# description           Local One Owner,Loaded,Navigation,Blindspot,Le...
# dim_bed                                                             NaN
# dim_height                                                      56.9 in
# dim_length                                                     192.7 in
# dim_wheelbase                                                  111.2 in
# dim_width                                                       72.4 in
# engine_cyl                                                           I4
# engine_disp                                                      2500.0
# engine_hp                                                           206
# engine_torque                                     186 lb-ft @ 5,000 RPM
# engine_type                                                          I4
# fleet                                                             False
# frame_damaged                                                     False
# franchise_dealer                                                   True
# franchise_make                                                 Cadillac
# fuel_capacity                                                    16 gal
# fuel_type                                                      Gasoline
# has_accidents                                                     False
# is_cpo                                                              NaN
# is_new                                                            False
# is_oemcpo                                                           NaN
# is_taxi                                                           False
# latitude                                                        34.5634
# legroom_back                                                      38 in
# legroom_front                                                   42.1 in
# listed_date                                                    24000448
# listing_color                                                    SILVER
# longitude                                                    -86.973198
# major_options         ['Sunroof/Moonroof', 'Navigation System', 'Bac...
# make_name                                                        Toyota
# mileage                                                         17811.0
# model_name                                                        Camry
# model_year                                                         2019
# mpg_city                                                           28.0
# mpg_hwy                                                            39.0
# owner_count                                                           1
# power                                                206 hp @ 6,600 RPM
# price                                                           28995.0
# salvage                                                           False
# seats                                                           5 seats
# seller_rating                                         4.857142857142857
# theft_title                                                       False
# transmission                                                          A
# transmission_display                                  8-Speed Automatic
# trimId                                                           t80278
# trim_name                                                       XSE FWD
# vin                                                   4T1B61HK6KU785439
# wheel_system                                                        FWD

# %%
# set VIN as index
df.set_index("vin", inplace=True)

# %%
# extract number from fields with units and other text
cols = ['legroom_back'
        ,'dim_bed'
        ,'legroom_front'
        ,'fuel_capacity'
        ,'dim_height'
        ,'dim_length'
        ,'seats'
        ,'dim_wheelbase'
        ,'dim_width'
        ]

for col in cols:
    first_ob = df[df[col].notna()][col].iloc[0]
    unit_loc = first_ob.find(' ') - len(first_ob)
    df[col] = df[col].str.slice(0,unit_loc).replace('',np.nan).astype(float)

# all dimensions are in inches

# %%
df[cols].dtypes
# Out:
# legroom_back     float64
# dim_bed          float64
# legroom_front    float64
# fuel_capacity    float64
# dim_height       float64
# dim_length       float64
# seats            float64
# dim_wheelbase    float64
# dim_width        float64
# dtype: object

# %%
# extract engine cylinders
df['engine_cyl'] = df['engine_cyl'].str.replace(r'\D','',regex=True).astype(float)

# %%
df.memory_usage().sum() / 1024**2
# Out:
# 341.8736515045166

# %%
df.to_parquet('data/cargurus_kaggle_clean.parquet')

# %% [markdown]
# ---
# ---
# ---

# %%
# parse horsepower, torque, and rpms
# re.findall(r'\d+\,?\d*','355 hp @ 5,600 RPM')

# %%
# extract number of gears, transmission features
# df.groupby(['transmission','transmission_display']).size()
# Out:
# transmission  transmission_display
# A             1-Speed Automatic                       116
#               10-Speed Automatic                        5
#               2-Speed Automatic                         7
#               3-Speed Automatic                        22
#               4-Speed Automatic                      1069
#               4-Speed Automatic Overdrive             284
#               5-Speed Automatic                      1325
#               5-Speed Automatic Overdrive             352
#               6-Speed Automatic                      9788
#               6-Speed Automatic Overdrive            1875
#               7-Speed Automatic                      1019
#               7-Speed Automatic Overdrive              35
#               8-Speed Automatic                      4102
#               8-Speed Automatic Overdrive             135
#               9-Speed Automatic                      1387
#               9-Speed Automatic Overdrive              39
#               Automatic                             20782
# CVT           1-Speed CVT                               8
#               6-Speed CVT                              14
#               7-Speed CVT                              59
#               8-Speed CVT                               1
#               Continuously Variable Transmission     6224
# Dual Clutch   1-Speed Dual Clutch                       5
#               6-Speed Dual Clutch                     122
#               7-Speed Dual Clutch                      19
#               8-Speed Dual Clutch                      43
# M             3-Speed Manual                            6
#               4-Speed Manual                           21
#               5-Speed Manual                          245
#               5-Speed Manual Overdrive                 17
#               6-Speed Manual                          515
#               6-Speed Manual Overdrive                 28
#               7-Speed Manual                           13
#               8-Speed Manual                            1
#               Manual                                  460
# dtype: int64

# %%
# numeric
df.describe().round(decimals = 1).T
# Out:
#                  count     mean      std     min      25%      50%      75%  \
# daysonmarket   50948.0     56.8    103.5     0.0     13.0     29.0     57.0
# dim_bed         6048.0     72.6      9.2    41.5     67.1     69.3     78.8
# dim_height     48692.0     65.0      7.4    43.7     57.9     65.8     69.9
# dim_length     48692.0    192.8     18.6   106.1    182.0    189.8    199.9
# dim_wheelbase  48694.0    114.3     13.2    73.5    106.3    110.6    116.2
# dim_width      48692.0     77.7      7.3    55.0     72.4     75.8     81.8
# engine_cyl     49645.0      5.2      1.5     2.0      4.0      4.0      6.0
# engine_disp    48830.0   3049.5   1307.9   700.0   2000.0   2500.0   3600.0
# engine_hp      48830.0    246.6     88.1    67.0    175.0    245.0    300.0
# fuel_capacity  48669.0     18.7      5.2     1.9     15.3     18.0     21.1
# latitude       50948.0     37.2      4.9    21.3     33.7     38.3     41.1
# legroom_back   47313.0     37.5      3.2     0.0     35.8     37.8     39.4
# legroom_front  48361.0     42.2      1.5    35.8     41.2     42.0     43.0
# longitude      50948.0    -90.5     14.0  -157.9    -97.0    -86.8    -80.2
# mileage        50388.0  58636.0  47622.2    50.0  25080.0  41132.0  84022.2
# model_year     50948.0   2015.4      4.8  1928.0   2014.0   2017.0   2018.0
# mpg_city       42791.0     21.8      8.0     8.0     17.0     21.0     25.0
# mpg_hwy        42791.0     29.0      7.5    12.0     24.0     28.0     33.0
# owner_count    49443.0      1.5      0.9     1.0      1.0      1.0      2.0
# price          50948.0  22582.7  18549.8   300.0  13500.0  19296.0  28491.0
# seats          48691.0      5.5      1.2     2.0      5.0      5.0      6.0
# seller_rating  50048.0      4.3      0.5     1.0      4.0      4.4      4.6
#
#                      max
# daysonmarket      3573.0
# dim_bed             98.6
# dim_height         114.2
# dim_length         290.0
# dim_wheelbase      201.0
# dim_width          109.0
# engine_cyl          12.0
# engine_disp       8400.0
# engine_hp          808.0
# fuel_capacity       52.0
# latitude            48.9
# legroom_back        47.5
# legroom_front       67.0
# longitude          -68.0
# mileage         388726.0
# model_year        2021.0
# mpg_city           127.0
# mpg_hwy            127.0
# owner_count         18.0
# price          1448880.0
# seats               15.0
# seller_rating        5.0

# %%
# non-numeric
pd.set_option('display.max_colwidth', 25)
df.describe(include = ['object','category']).T
# Out:
#                       count unique                       top   freq
# bed                     591      3                     Short    367
# body_type             50888      9           SUV / Crossover  21419
# cabin                  1308      4                  Crew Cab    962
# city                  50948   3770                   Houston    713
# color_exterior        50948   3407                     Black   3928
# color_interior        50938   2490                     Black  14313
# dealer_zip            50948   6523                     77477    198
# description           50071  49525  All advertised prices...     15
# engine_torque         44619   1295     383 lb-ft @ 4,100 RPM   1520
# engine_type           49645     31                        I4  23174
# fleet                 50883      2                     False  39647
# frame_damaged         50883      2                     False  50372
# franchise_make        31986     43                 Chevrolet   4940
# fuel_type             49868      7                  Gasoline  44284
# has_accidents         50883      2                     False  42738
# is_cpo                 6031      1                      True   6031
# is_oemcpo              4500      1                      True   4500
# is_taxi               50883      2                     False  41325
# listed_date           50948    772                2020-09-02   1470
# listing_color         50948     15                     WHITE  11045
# major_options         48635  14318  ['Alloy Wheels', 'Blu...   2385
# make_name             50948     62                      Ford   7200
# model_name            50948    866                     F-150   1571
# power                 45529   1292        355 hp @ 5,600 RPM   1520
# salvage               50883      2                     False  50545
# theft_title           50883      2                     False  50678
# transmission          50143      4                         A  42342
# transmission_display  50143     35                 Automatic  20782
# trimId                49510  13678                    t82263    160
# trim_name             49496   3646                        SE   1066
# wheel_system          49261      5                       FWD  22288

# %%
# five example obs
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 500)

df.sample(3).T
# Out:
# vin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1J4GL58505W583249  \
# back_legroom                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         37.2
# bed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# bed_length                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# body_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 SUV / Crossover
# cabin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# city                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Hastings
# color_exterior                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Bright Silver Metallic Clearcoat
# color_interior                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Brown (Dark Khaki/Light Graystone)
# daysonmarket                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           14
# dealer_zip                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          68901
# description           Recent Arrival! 2005 Jeep Liberty Limited 22/27 City/Highway MPG FRESH OIL CHANGE, RECENT DINSDALE TRADE IN, SUNROOF MOONROOF, 4 WHEEL DRIVE, Liberty Limited, 4D Sport Utility, 2.8L 4-Cylinder Turbocharged, 5-Speed Automatic, 4WD, Bright Silver Metallic Clearcoat, Dark Khaki/Light Graystone w/Premium Leather Trimmed Bucket Seats, Power Sunroof, 3.73 Axle Ratio, 4-Wheel Disc Brakes, 6 Speakers, Air Conditioning, Alloy wheels, AM/FM Compact Disc w/Changer Control, AM/FM radio, Bodyside molding...
# engine_cylinders                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      4.0
# engine_displacement                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                2800.0
# engine_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I4 Diesel
# fleet                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               False
# frame_damaged                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       False
# franchise_dealer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     True
# franchise_make                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Jeep
# front_legroom                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        40.8
# fuel_capacity                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        20.0
# fuel_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Diesel
# has_accidents                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        True
# height                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               71.1
# horsepower                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          160.0
# isCab                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               False
# is_cpo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# is_new                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              False
# is_oemcpo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# latitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          40.6131
# length                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              174.4
# listed_date                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2020-08-28
# listing_color                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      SILVER
# longitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        -98.3825
# major_options                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['Sunroof/Moonroof', 'Alloy Wheels']
# make_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Jeep
# mileage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          151806.0
# model_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Liberty
# model_year                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           2005
# mpg_city                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             19.0
# mpg_hwy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              24.0
# owner_count                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           2.0
# power                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  210 hp @ 5,200 RPM
# price                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              7923.0
# salvage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             False
# seats                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5.0
# seller_rating                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         4.5
# theft_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         False
# torque                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              235 lb-ft @ 4,000 RPM
# transmission                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            A
# transmission_display                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    5-Speed Automatic
# trimId                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              t7010
# trim_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Limited 4WD
# wheel_system                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          4WD
# wheelbase                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           104.3
# width                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                71.6
#
# vin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     5UXTS3C5XK0Z04391  \
# back_legroom                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         36.4
# bed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# bed_length                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# body_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 SUV / Crossover
# cabin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# city                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Tuscaloosa
# color_exterior                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Alpine White
# color_interior                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Brown (Canberra Beige/Black)
# daysonmarket                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           10
# dealer_zip                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          35405
# description           Odometer is 5166 miles below market average! CARFAX One-Owner. Clean CARFAX. 8-Speed Automatic, Wheels: 20" x 8.0" Fr/20" x 9.5" Rr (Style 699M).   BMW of Tuscaloosa presents this 2019 BMW X3 M40i Sports Activity Vehicle in Alpine White with Canberra Beige Leather.    Nicely equipped with Driving Assistance Package (Active Blind Spot Detection and Active Driving Assistant), Driving Assistance Plus Package (ACC Stop & Go + Active Driving Assistant and Extended Collision Mitigation), Executive...
# engine_cylinders                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      6.0
# engine_displacement                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                3000.0
# engine_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            I6
# fleet                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               False
# frame_damaged                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       False
# franchise_dealer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     True
# franchise_make                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        BMW
# front_legroom                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        40.3
# fuel_capacity                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        17.2
# fuel_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Gasoline
# has_accidents                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       False
# height                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               66.0
# horsepower                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          355.0
# isCab                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               False
# is_cpo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# is_new                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              False
# is_oemcpo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# latitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          33.1704
# length                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              186.1
# listed_date                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2020-09-01
# listing_color                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       WHITE
# longitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        -87.4889
# major_options                                                                                                                                                                                                                                                                                                                                                                             ['Sunroof/Moonroof', 'Executive Package', 'Navigation System', 'Alloy Wheels', 'Bluetooth', 'Backup Camera', 'Premium Package', 'Heated Seats']
# ...
# is_cpo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# is_new                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              False
# is_oemcpo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# latitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          41.2384
# length                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              191.9
# listed_date                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2020-09-05
# listing_color                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        GRAY
# longitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        -81.7946
# major_options                                                                                                                                                                                                                                                                                                                                                              ['Sunroof/Moonroof', 'Navigation System', 'Adaptive Cruise Control', 'Alloy Wheels', 'Backup Camera', 'Remote Start', 'Blind Spot Monitoring', 'Heated Seats']
# make_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Volkswagen
# mileage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            6435.0
# model_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Passat
# model_year                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           2017
# mpg_city                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             23.0
# mpg_hwy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              34.0
# owner_count                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1.0
# power                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  170 hp @ 6,200 RPM
# price                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             18990.0
# salvage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             False
# seats                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5.0
# seller_rating                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    4.695652
# theft_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         False
# torque                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              184 lb-ft @ 1,500 RPM
# transmission                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            A
# transmission_display                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Automatic
# trimId                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             t69429
# trim_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1.8T SE with Technology Pkg
# wheel_system                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          FWD
# wheelbase                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           110.4
# width                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                72.2

# %% [markdown]
# ### Missing

# %%
# missing values
nulls = pd.DataFrame(data = {'count':df.isna().sum()})
nulls['pct'] = nulls['count'] / df.shape[0]
nulls.sort_values(by = 'count', ascending = False)
# Out:
#                       count       pct
# bed                   50357  0.988400
# cabin                 49640  0.974327
# is_oemcpo             46448  0.911675
# is_cpo                44917  0.881624
# bed_length            44900  0.881291
# franchise_make        18962  0.372183
# mpg_hwy                8157  0.160104
# mpg_city               8157  0.160104
# torque                 6329  0.124225
# power                  5419  0.106363
# back_legroom           3635  0.071347
# front_legroom          2587  0.050777
# major_options          2313  0.045399
# fuel_capacity          2279  0.044732
# seats                  2257  0.044300
# length                 2256  0.044280
# height                 2256  0.044280
# width                  2256  0.044280
# wheelbase              2254  0.044241
# engine_displacement    2118  0.041572
# horsepower             2118  0.041572
# wheel_system           1687  0.033112
# owner_count            1505  0.029540
# trim_name              1452  0.028500
# trimId                 1438  0.028225
# engine_cylinders       1303  0.025575
# engine_type            1303  0.025575
# fuel_type              1080  0.021198
# seller_rating           900  0.017665
# description             877  0.017214
# transmission_display    805  0.015800
# transmission            805  0.015800
# mileage                 560  0.010992
# has_accidents            65  0.001276
# fleet                    65  0.001276
# frame_damaged            65  0.001276
# isCab                    65  0.001276
# theft_title              65  0.001276
# salvage                  65  0.001276
# body_type                60  0.001178
# color_interior           10  0.000196
# listed_date               0  0.000000
# is_new                    0  0.000000
# dealer_zip                0  0.000000
# price                     0  0.000000
# daysonmarket              0  0.000000
# listing_color             0  0.000000
# city                      0  0.000000
# latitude                  0  0.000000
# color_exterior            0  0.000000
# model_year                0  0.000000
# franchise_dealer          0  0.000000
# make_name                 0  0.000000
# longitude                 0  0.000000
# model_name                0  0.000000

# %%
# drop columns with > 80% missing values

# DON'T DROP BED LENGTH YET, CHECK IF NULL % FOR TRUCK ONLY

print(df.shape)
df.dropna(axis = 'columns', thresh = df.shape[0] * 0.8, inplace = True)
print(df.shape)

# %%
msno.heatmap(df)

# %%
# missingness correlations
temp = df.iloc[:, [i for i, n in enumerate(np.var(df.isnull(), axis='rows')) if n > 0]]
corr_mat = temp.isnull().corr()

corr_mat2 = corr_mat.unstack().reset_index()
corr_mat2.columns = ['var1','var2','corr']
corr_mat2['var_min'] = corr_mat2[['var1','var2']].min(axis=1)
corr_mat2['var_max'] = corr_mat2[['var1','var2']].max(axis=1)
corr_mat2.drop(columns=['var1','var2'], inplace=True)
corr_mat2.drop_duplicates(inplace=True)
corr_mat2 = corr_mat2[corr_mat2['var_min'] != corr_mat2['var_max']]
corr_mat2 = corr_mat2[corr_mat2['corr'] > 0.1]
corr_mat2.sort_values(by='corr', ascending=False)

# %% [markdown]
# #### Mileage
# Mileage is an essential feature expected to have a large impact on the model. Better to drop than impute.

# %%
print(df.shape)
print(df['mileage'].isna().sum())
df = df[df['mileage'].notna()]
print(df.shape)

# %% [markdown]
# Mileage is mostly missing on new vehicles

# %% [markdown]
# ### Augmentation

# %% [markdown]
# #### States

# %%
# add state
df['state'] = np.nan

for i in df.index:
    search = SearchEngine()
    zipcode = search.by_zipcode(df.loc[i,'dealer_zip'])
    try:
        df.loc[i,'state'] = zipcode.state
    except:
        pass
    else:
        df.loc[i,'state'] = zipcode.state

print('state not found:',df['state'].isna().sum())

# %%
print((df['state'].value_counts()).round(decimals = 2).head(10))

# %%
print((df['state'].value_counts())[['TX','OH','VA']].round(decimals = 2))
print((df['state'].value_counts()/df.shape[0])[['TX','OH','VA']].round(decimals = 2))
print((df['state'].value_counts()/df.shape[0])[['TX','OH','VA']].sum().round(decimals = 2))
print(f'{0.18*3000000:,}')
