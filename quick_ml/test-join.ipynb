# %% [markdown]
# # Test Join
# We have enough to look at what we're going to have. Let's take a look!

# %%
import pandas as pd
import pyarrow as pa

# %%
# increase pandas display row limit
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Listings

# %%
mc = pd.read_parquet('part-00272-bbdecf64-de8c-4648-b96c-e44fb6cd17e1-c000.snappy.parquet', engine='pyarrow')
print(mc.shape)
# Out:
# (13819, 71)

# %% [markdown]
# For simplicity sake, I'm dropping additional registrations for the same VIN. In practice will need to do some kind of date precedent logic.

# %%
# deduplicate mc_tx by vin and keep the first record
mc = mc.drop_duplicates(subset='vin', keep='first')
print(mc.shape)
# Out:
# (13666, 71)

# %%
mc['state'].value_counts()
# Out:
# TX    8072
# OH    3379
# TN    2214
# Name: state, dtype: int64

# %%
mc.sample(5).T
# Out:
#                                                                   5427  \
# id                                     JM3KFBDM0J0392857-616741f4-f644
# vin                                                  JM3KFBDM0J0392857
# heading                              2018 Mazda CX-5 Grand Touring SUV
# price                                                          22249.0
# msrp                                                           22249.0
# miles                                                          40931.0
# stock_no                                                       20750PR
# year                                                            2018.0
# make                                                             Mazda
# model                                                             CX-5
# trim                                                     Grand Touring
# vehicle_type                                                     Truck
# body_type                                                          SUV
# body_subtype                                                      None
# drivetrain                                                         4WD
# fuel_type                                                     Unleaded
# engine                                                         2.5L I4
# engine_block                                                         I
# engine_size                                                        2.5
# engine_measure                                                    None
# engine_aspiration                                                 None
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          4.0
# city_mpg                                                          24.0
# highway_mpg                                                       30.0
# interior_color                                                   Black
# exterior_color                                  Deep Crystal Blue Mica
# base_exterior_color                                               Blue
# base_interior_color                                              Black
# is_certified                                                       NaN
# is_transfer                                                        NaN
# taxonomy_vin                                                JM3KFBDMJ0
# scraped_at                                                  1575288384
# status_date                                                 1575550170
# first_scraped_at                                            1572364188
# source                                    ganleyalfaromeoofbedford.com
# seller_name                          Ganley Alfa Romeo Fiat of Bedford
# city                                                           Bedford
# state                                                               OH
# zip                                                              44146
# latitude                                                       41.4007
# longitude                                                   -81.549202
# dealer_type                                                  franchise
# car_seller_name                      Ganley Alfa Romeo FIAT of Bedford
# car_city                                                          None
# car_state                                                         None
# car_zip                                                           None
# car_latitude                                                       NaN
# car_longitude                                                      NaN
# seller_comments      2018 Mazda CX-5 Grand Touring Leather Seats, H...
# dom                                                               38.0
# dom_180                                                           38.0
# dom_active                                                        38.0
# currency_indicator                                                None
# miles_indicator                                                  MILES
# carfax_1_owner                                                     0.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           NaN
# l_down_pay                                                         NaN
# l_emi                                                              NaN
# f_down_pay                                                         NaN
# f_down_pay_per                                                     NaN
# f_emi                                                              NaN
# lease_term                                                         NaN
# photo_links_count                                                   49
# photo_main                                                        True
# listed_options       [Speakers: 10, Alloy wheels, Engine horsepower...
# hvf_options          [[Coming Home Device, Adaptive Cruise Control,...
#
#                                                                   3594  \
# id                   5TDYK3DC7FS545539-d4cc1f84-ad8e-418e-b164-8602...
# vin                                                  5TDYK3DC7FS545539
# heading              2015 TOYOTA SIENNA XLE PREM 8-PASS SUNROOF NAV...
# price                                                          27730.0
# msrp                                                               NaN
# miles                                                          26112.0
# stock_no                                                        545539
# year                                                            2015.0
# make                                                            Toyota
# model                                                           Sienna
# trim                                                               XLE
# vehicle_type                                                     Truck
# body_type                                                      Minivan
# body_subtype                                                      None
# drivetrain                                                         FWD
# fuel_type                                                     Unleaded
# engine                                                         3.5L V6
# engine_block                                                         V
# engine_size                                                        3.5
# engine_measure                                                    None
# engine_aspiration                                                 None
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          6.0
# city_mpg                                                          18.0
# highway_mpg                                                       25.0
# interior_color                                                Lt. Gray
# exterior_color                                       Creme Brulee Mica
# base_exterior_color                                              Beige
# base_interior_color                                               Gray
# is_certified                                                       NaN
# is_transfer                                                        NaN
# taxonomy_vin                                                5TDYK3DCFS
# scraped_at                                                  1513387776
# status_date                                                 1513389056
# first_scraped_at                                                  None
# source                                             texasdirectauto.com
# seller_name                                          texas direct auto
# city                                                          Stafford
# state                                                               TX
# zip                                                              77477
# latitude                                                     29.620001
# longitude                                                   -95.559998
# dealer_type                                                       None
# car_seller_name                                                   None
# car_city                                                          None
# car_state                                                         None
# car_zip                                                           None
# car_latitude                                                       NaN
# car_longitude                                                      NaN
# seller_comments                                                   None
# dom                                                                4.0
# dom_180                                                            4.0
# dom_active                                                         4.0
# currency_indicator                                                None
# miles_indicator                                                   None
# carfax_1_owner                                                     NaN
# carfax_clean_title                                                 NaN
# loan_term                                                          NaN
# loan_apr                                                           NaN
# l_down_pay                                                         NaN
# l_emi                                                              NaN
# f_down_pay                                                         NaN
# f_down_pay_per                                                     NaN
# f_emi                                                              NaN
# lease_term                                                         NaN
# photo_links_count                                                   30
# photo_main                                                       False
# listed_options       [Power Side Doors, Power Door Locks, Audio Ste...
# hvf_options                                                   [[], []]
#
#                                                                   8672  \
# id                   WBA8E9C55GK646680-bf551e16-647e-44af-93d0-8f79...
# vin                                                  WBA8E9C55GK646680
# heading                                   2016 BMW 3 Series 328i Sedan
# price                                                          20991.0
# msrp                                                           20991.0
# miles                                                          38538.0
# stock_no                                                      GK646680
# year                                                            2016.0
# make                                                               BMW
# model                                                         3 Series
# trim                                                              328i
# vehicle_type                                                       Car
# body_type                                                        Sedan
# body_subtype                                                      None
# drivetrain                                                         RWD
# fuel_type                                             Premium Unleaded
# engine                                                         2.0L I4
# engine_block                                                         I
# engine_size                                                          2
# engine_measure                                                    None
# engine_aspiration                                                 None
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              4.0
# cylinders                                                          4.0
# city_mpg                                                          23.0
# highway_mpg                                                       35.0
# interior_color                               VENETIAN BEIGE/DRK OYSTER
# exterior_color                                               Jet Black
# base_exterior_color                                              Black
# base_interior_color                                              Beige
# is_certified                                                       0.0
# is_transfer                                                        NaN
# taxonomy_vin                                                WBA8E9C5GK
# scraped_at                                                  1564585388
# status_date                                                 1565454662
# first_scraped_at                                            1452409200
# source                               www.genesisofsouthwesthouston.com
# seller_name                               genesis of southwest houston
# city                                                           Houston
# state                                                               TX
# zip                                                              77074
# latitude                                                     29.664499
# longitude                                                   -95.551804
# dealer_type                                                  franchise
# car_seller_name                                                   None
# car_city                                                          None
# car_state                                                         None
# car_zip                                                           None
# car_latitude                                                       NaN
# car_longitude                                                      NaN
# seller_comments      We are excited to offer this 2016 BMW 3 Series...
# dom                                                              154.0
# dom_180                                                           11.0
# dom_active                                                        11.0
# currency_indicator                                                None
# miles_indicator                                                   None
# carfax_1_owner                                                     0.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           NaN
# l_down_pay                                                         NaN
# l_emi                                                              NaN
# f_down_pay                                                         NaN
# f_down_pay_per                                                     NaN
# f_emi                                                              NaN
# lease_term                                                         NaN
# photo_links_count                                                    9
# photo_main                                                        True
# listed_options       [Garage door transmitter, Alloy wheels, Engine...
# hvf_options          [[Coming Home Device, Keyless Entry/Locking, K...
#
#                                                                   3492  \
# id                                     5TDGZRBH5MS154153-5983ec16-b541
# vin                                                  5TDGZRBH5MS154153
# heading                      Certified Used 2021 Toyota Highlander XLE
# price                                                          44669.0
# msrp                                                           44995.0
# miles                                                          11580.0
# stock_no                                                         B-356
# year                                                            2021.0
# make                                                            Toyota
# model                                                       Highlander
# trim                                                               XLE
# vehicle_type                                                     Truck
# body_type                                                          SUV
# body_subtype                                                      None
# drivetrain                                                         4WD
# fuel_type                                                     Unleaded
# engine                                                         3.5L V6
# engine_block                                                         V
# engine_size                                                        3.5
# engine_measure                                                    None
# engine_aspiration                                                 None
# transmission                                                 Automatic
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          6.0
# city_mpg                                                          20.0
# highway_mpg                                                       27.0
# interior_color                                                   Black
# exterior_color                                                    Gray
# base_exterior_color                                               Gray
# base_interior_color                                              Black
# is_certified                                                       1.0
# is_transfer                                                        NaN
# taxonomy_vin                                                5TDGZRBHMS
# scraped_at                                                  1655398236
# status_date                                                 1655398236
# first_scraped_at                                            1631745800
# source                                                 germaincars.com
# seller_name                                               Germain Cars
# city                                                          Columbus
# state                                                               OH
# zip                                                              43219
# latitude                                                     40.056675
# longitude                                                   -82.917809
# dealer_type                                                  franchise
# car_seller_name                                                   None
# car_city                                                          None
# car_state                                                         None
# car_zip                                                           None
# car_latitude                                                       NaN
# car_longitude                                                      NaN
# seller_comments      Recent Arrival! CARFAX One-Owner. AWD. Odomete...
# dom                                                               34.0
# dom_180                                                            5.0
# dom_active                                                         5.0
# currency_indicator                                                 USD
# miles_indicator                                                  MILES
# carfax_1_owner                                                     1.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           NaN
# l_down_pay                                                         NaN
# l_emi                                                              NaN
# f_down_pay                                                         NaN
# f_down_pay_per                                                     NaN
# f_emi                                                              NaN
# lease_term                                                         NaN
# photo_links_count                                                    1
# photo_main                                                        True
# listed_options       [Alloy wheels, Front reading lights, Outside t...
# hvf_options          [[Rear/Multi-Zone Air Conditioning, Power Clos...
#
#                                                                   5731
# id                   JN8AT2MT3HW399124-fa835b55-9439-46b2-8d0e-79d2...
# vin                                                  JN8AT2MT3HW399124
# heading                                 Pre-Owned 2017 Nissan Rogue SV
# price                                                          20000.0
# msrp                                                           20000.0
# miles                                                          23156.0
# stock_no                                                        NP2411
# year                                                            2017.0
# make                                                            Nissan
# model                                                            Rogue
# trim                                                                SV
# vehicle_type                                                     Truck
# body_type                                                          SUV
# body_subtype                                                      None
# drivetrain                                                         FWD
# fuel_type                                                     Unleaded
# engine                                                         2.5L I4
# engine_block                                                         I
# engine_size                                                        2.5
# engine_measure                                                    None
# engine_aspiration                                                 None
# transmission                                                       CVT
# speeds                                                             NaN
# doors                                                              5.0
# cylinders                                                          4.0
# city_mpg                                                          26.0
# highway_mpg                                                       33.0
# interior_color                                                  Almond
# exterior_color                                                   White
# base_exterior_color                                              White
# base_interior_color                                              Brown
# is_certified                                                       0.0
# is_transfer                                                        NaN
# taxonomy_vin                                                JN8AT2MTHW
# scraped_at                                                  1567082096
# status_date                                                 1571578817
# first_scraped_at                                            1500703200
# source                                         www.wolfchasenissan.com
# seller_name                                           wolfchase nissan
# city                                                          Bartlett
# state                                                               TN
# zip                                                              38133
# latitude                                                        35.209
# longitude                                                   -89.791702
# dealer_type                                                  franchise
# car_seller_name                                                   None
# car_city                                                          None
# car_state                                                         None
# car_zip                                                           None
# car_latitude                                                       NaN
# car_longitude                                                      NaN
# seller_comments      ONE OWNER, CLEAN AUTOCHECK, HEATED SEATS, BACK...
# dom                                                               68.0
# dom_180                                                           53.0
# dom_active                                                        53.0
# currency_indicator                                                None
# miles_indicator                                                   None
# carfax_1_owner                                                     0.0
# carfax_clean_title                                                 0.0
# loan_term                                                          NaN
# loan_apr                                                           NaN
# l_down_pay                                                         NaN
# l_emi                                                              NaN
# f_down_pay                                                         NaN
# f_down_pay_per                                                     NaN
# f_emi                                                              NaN
# lease_term                                                         NaN
# photo_links_count                                                   38
# photo_main                                                       False
# listed_options       [Radio: AM/FM/CD/AUX, Alloy wheels, Front read...
# hvf_options          [[Keyless Entry/Locking, Keyless Start/Remote ...

# %% [markdown]
# ## Texas

# %%
tx = pd.read_parquet('~/Projects/used_car_pricing/data/tx_mvr/tx_mvr_out.parquet', engine='pyarrow')
print(tx.shape)

# %%
tx.sample(5).T
# Out:
#                            14587549           6907488            26004201  \
# VIN               3KPF24AD6KE094957  1FTFW1CF8CKD85461  1C6RR6TT2KS509317
# SALE_DATE              '2019-08-07'       '2018-10-23'       '2022-04-14'
# SALES_PRICE                 18535.0            10000.0                NaN
# ODOMETER_BRAND                    A                  A                  A
# ODOMETER_READING                 99             178314              73478
# DOCNO             05731543682250485  15232643394104017  20820044663115943
# VEHYEAR                        2019               2012               2019
# MAKE                           KIA                FORD               RAM
# MODEL                           FOR                F15                150
# BODY_TYPE                        4D                 PK                 PK
# OWNERSHIP_CD                      6                  1                  1
# TTL_SIGNED_DATE            20190708           20180707           20220317
# OWNER_ZIP                     75062              79549              79549
# OWNER_ZIP+4                     NaN                NaN                NaN
# RENEW_ZIP                       NaN                NaN                NaN
# RENEW_ZIP+4                     NaN                NaN                NaN
# RECONDITION_CD                  NaN                NaN                  1
# SALVSTATECNTRY                  NaN                NaN                NaN
#
#                            23129461           2554148
# VIN               1FTFW1CT4DFD10529  5TFJU4GN8DX048182
# SALE_DATE              '2021-08-06'       '2018-02-20'
# SALES_PRICE                     NaN       23682.929688
# ODOMETER_BRAND                    A                  A
# ODOMETER_READING             152225              65221
# DOCNO             10149444412075223  22125043149140930
# VEHYEAR                        2013               2013
# MAKE                           FORD               TOYT
# MODEL                           F15                TAC
# BODY_TYPE                        PK                 PK
# OWNERSHIP_CD                      1                  1
# TTL_SIGNED_DATE            20210527           20180116
# OWNER_ZIP                     77071              79602
# OWNER_ZIP+4                     NaN                NaN
# RENEW_ZIP                       NaN                NaN
# RENEW_ZIP+4                     NaN                NaN
# RECONDITION_CD                  NaN                NaN
# SALVSTATECNTRY                  NaN                NaN

# %%
# dedupe tx by vin and keep the first record
tx = tx.drop_duplicates(subset='VIN', keep='first')
print(tx.shape)

# %%
# join mc_tx and tx on vin = VIN
tx_match = mc.merge(tx, left_on='vin', right_on='VIN', how='inner')

# %%
# match rate
tx_match.shape[0] / mc[mc['state'] == 'TX'].shape[0]
# Out:
# 0.8002973240832507

# %%
# save to parquet
tx_match.to_parquet('tx_match.parquet', engine='pyarrow')

# %% [markdown]
# ## Ohio

# %%
oh = pd.read_parquet('~/Projects/used_car_pricing/data/oh_mvr/oh_mvr_out.parquet', engine='pyarrow')
print(oh.shape)
# Out:
# (28591523, 24)

# %%
oh.sample(5).T
# Out:
#                                          10095110              19745438  \
# TitleNumber                            2800818475            4806216486
# IssueDate                     2018-11-19 00:00:00   2022-01-11 00:00:00
# TitleStatus                                ACTIVE                ACTIVE
# TitleType                                ORIGINAL              ORIGINAL
# VIN                             1C4PJMCSXFW521538     1GR1A0621LW174726
# Year                                         2015                  2020
# Make                                         JEEP       GREAT DANE TRAI
# Model                                    CHEROKEE                   ---
# BodyType                            STATION WAGON                   VAN
# NewOrUsed                                    Used                  Used
# Mileage                                   49194.0                   NaN
# MileageBrand                               ACTUAL                   NaN
# MileageJustificationType                      NaN       ODOMETER EXEMPT
# NMVTISBrand1                                  NaN                   NaN
# NMVTISBrand2                                  NaN                   NaN
# NMVTISBrand3                                  NaN                   NaN
# PurchaseDate                  2018-11-16 00:00:00   2022-01-06 00:00:00
# PurchasePrice                             18891.0                   0.0
# OwnerType                              INDIVIDUAL                DEALER
# OwnerName                                    None  PRIDE TRUCK SALES LP
# PrevOwnerType                              DEALER               COMPANY
# PrevOwnerName             JUNCTION AUTO SALES INC                  None
# CountyofResidence                        TRUMBULL                 LUCAS
# PreviousStateCode                              OH                    CA
#
#                                      28092735  \
# TitleNumber                         906111381
# IssueDate                 2022-10-14 00:00:00
# TitleStatus                          INACTIVE
# TitleType                            ORIGINAL
# VIN                         1GCWGFFAXB1116313
# Year                                     2011
# Make                                CHEVROLET
# Model                                      --
# BodyType                                  VAN
# NewOrUsed                                Used
# Mileage                              188332.0
# MileageBrand                           ACTUAL
# MileageJustificationType                  NaN
# NMVTISBrand1                              NaN
# NMVTISBrand2                              NaN
# NMVTISBrand3                              NaN
# PurchaseDate              2022-10-14 00:00:00
# PurchasePrice                             0.0
# OwnerType                              DEALER
# OwnerName                  DIXIE AUTOMART LLC
# PrevOwnerType                          DEALER
# PrevOwnerName              DIXIE AUTOMART LLC
# CountyofResidence                      BUTLER
# PreviousStateCode                          OH
#
#                                                           18340745  \
# TitleNumber                                             3108875276
# IssueDate                                      2020-02-06 00:00:00
# TitleStatus                                                 ACTIVE
# TitleType                                                 ORIGINAL
# VIN                                              1N4BA41E84C895433
# Year                                                          2004
# Make                                                        NISSAN
# Model                                                       MAXIMA
# BodyType                                                 FOUR DOOR
# NewOrUsed                                                     Used
# Mileage                                                   192601.0
# MileageBrand              NON-ACTUAL WARNING: ODOMETER DISCREPANCY
# MileageJustificationType                                       NaN
# NMVTISBrand1                                                   NaN
# NMVTISBrand2                                                   NaN
# NMVTISBrand3                                                   NaN
# PurchaseDate                                   2020-01-17 00:00:00
# PurchasePrice                                               1000.0
# OwnerType                                               INDIVIDUAL
# OwnerName                                                     None
# PrevOwnerType                                              COMPANY
# PrevOwnerName                                                 None
# CountyofResidence                                           BUTLER
# PreviousStateCode                                               OH
#
#                                                     25077100
# TitleNumber                                       8100493555
# IssueDate                                2022-07-07 00:00:00
# TitleStatus                                         INACTIVE
# TitleType                                           ORIGINAL
# VIN                                        1FT7W2B69KED22748
# Year                                                    2019
# Make                                                    FORD
# Model                                                   F250
# BodyType                                        PICKUP TRUCK
# NewOrUsed                                               Used
# Mileage                                              60919.0
# MileageBrand                                          ACTUAL
# MileageJustificationType                                 NaN
# NMVTISBrand1                                             NaN
# NMVTISBrand2                                             NaN
# NMVTISBrand3                                             NaN
# PurchaseDate                             2022-06-30 00:00:00
# PurchasePrice                                   55390.191406
# OwnerType                                         INDIVIDUAL
# OwnerName                                               None
# PrevOwnerType                                         DEALER
# PrevOwnerName             STATEWIDE FORD LINCOLN MERCURY INC
# CountyofResidence                                   VAN WERT
# PreviousStateCode                                         OH

# %% [markdown]
# Ohio is unique in that they require registration of dealer-to-dealer transactions. Here I'm dropping dealer-to-dealer because it's not a transaction we're interested in, and it's not comparable to the data we have from the other states.

# %%
# filter out rows where both OwnerType = 'DEALER' and PrevOwnerType = 'DEALER'
oh = oh[~((oh['OwnerType'] == 'DEALER') & (oh['PrevOwnerType'] == 'DEALER'))]
print(oh.shape)
# Out:
# (25325711, 24)

# %%
# dedupe by vin and keep the first record
oh = oh.drop_duplicates(subset='VIN', keep='first')
print(oh.shape)
# Out:
# (12837148, 24)

# %%
# join on vin
oh_match = mc.merge(oh, left_on='vin', right_on='VIN', how='inner')

# %%
# match rate
oh_match.shape[0] / mc[mc['state'] == 'OH'].shape[0]
# Out:
# 0.9446581828943474

# %%
# save to parquet
oh_match.to_parquet('oh_match.parquet', engine='pyarrow')

# %% [markdown]
# ## Tennessee

# %%
tn = pd.read_parquet('~/Projects/used_car_pricing/data/tn_mvr/tn_mvr.parquet', engine='pyarrow')
print(tn.shape)
# Out:
# (9831774, 13)

# %%
tn.sample(5).T
# Out:
#                                2621566            6912672            2206334  \
# vin                  1JJV532D1NL306341  3MZBN1U75JM190168  1J4GK48K46W282715
# price                              0.0            17821.0                0.0
# odometer_type                        1                  0                  1
# mileage                              0                  4                  0
# county                        Davidson           Lawrence              State
# zip                              37209              38469              37355
# model_year                        2022               2018               2006
# make                              WANC               MAZD               JEEP
# model                              DVC                MZ3                LBY
# vehicle_type      FREIGHT/SEMI TRAILER               AUTO               AUTO
# new_used                             N                  N                  U
# title_issue_date            2021-10-26         2018-12-17         2022-11-10
# purchase_date               2021-09-09         2018-12-04         2022-09-21
#
#                             681427             8250810
# vin               1C6RR6MT5FS629598  VBKEXG400LM293799
# price                           0.0                0.0
# odometer_type                     0                  0
# mileage                       68401                  1
# county                        State           Fentress
# zip                           37043              38553
# model_year                     2015               2020
# make                            RAM                KTM
# model                           150                VBK
# vehicle_type                  TRUCK         MOTORCYCLE
# new_used                          U                  N
# title_issue_date         2021-05-14         2021-07-09
# purchase_date            2020-06-13         2020-11-02

# %%
tn.columns = ['vin', 'price_tn', 'odometer_type_tn', 'mileage_tn', 'county_tn', 'zip_tn',
       'model_year_tn', 'make_tn', 'model_tn', 'vehicle_type_tn', 'new_used_tn',
       'title_issue_date_tn', 'purchase_date_tn']

# %%
# dedupe by vin and keep the first record
tn = tn.drop_duplicates(subset='vin', keep='first')
print(tn.shape)
# Out:
# (7558173, 13)

# %%
# join on vin
tn_match = mc.merge(tn, on='vin', how='inner')

# %%
# match rate
tn_match.shape[0] / mc[mc['state'] == 'TN'].shape[0]
# Out:
# 0.6296296296296297

# %%
# save to parquet
tn_match.to_parquet('tn_match.parquet', engine='pyarrow')
